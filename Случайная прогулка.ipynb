# %%
from random import random
from matplotlib import pyplot
s = list()
a = list()
a.append(-1 if random() < 0.5 else 1)
for i in range(1, 1000):
    run = -1 if random() < 0.5 else 1
    value = a[i-1] + run
    a.append(value)
    if i>=10:
        if a[i]-a[i-10]>9 or a[i-10]-a[i]>9:
            s.append(i)
    if a[i]>a[i-1]:
        
pyplot.plot(a)
pyplot.show()
print('Минимальное значение:', min(a),
      'Максимальное значение:', max(a))
print('Первый момент времени, когда на прогулке было сделано более 10 шагов в одну сторону:', s[0])
# Out:
# Минимальное значение: -12 Максимальное значение: 23
# Первый момент времени, когда на прогулке было сделано более 10 шагов в одну сторону: 560
